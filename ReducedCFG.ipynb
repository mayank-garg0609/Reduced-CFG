# %%
#reading non-terminal
input_string = input("Enter Non-terminal separated by spaces: ")
vars = input_string.split()

if all(len(char) == 1 for char in vars):
  print("Characters entered:", vars)
else:
  print("Invalid input: Each entry should be a single character.")

#reading terminal
input_string = input("Enter Terminal separated by spaces: ")
const = input_string.split()

if all(len(char) == 1 for char in const):
  print("Characters entered:",const)
else:
  print("Invalid input: Each entry should be a single character.")




common_elements = set(vars) & set(const)
all_elements = set(vars) | set(const)
if common_elements:
  print("There are common characters in both Terminal and Non-terminal")
  if input("Do you want to restart the input process? (yes/no): ").lower() == 'yes':
    chars = []
  else:
    print("Exiting")
    sys.exit()

productions = []

#reading production rule
while True:
  string = input("Enter production rule for grammar (or type 'done' to finish) ")
  if string == 'done':
    break
  if len(string) > 0 and string[0] in vars:
    if all(char in all_elements for char in string[1:]):
      productions.append(string)
    else:
      print("The production rule of"+str(string[0])+"must contain only terminal and non-terminals")

  elif len(string)==0:
    print("You entered a empty string")
  else:
      print("1st char should be a Non-terminal")
for string in productions:
    print(string[0] + '->' + string[1:])

#reading starting terminal
while True:
    char = input("Enter Starting Terminal for grammar ")
    if len(char) == 1 and char in vars:
        start = char
        break
    elif len(char)!=1 :
        print("Please enter only one character ")
    else:
        print("Enter a char from Non-terminal only")


print("Starting Non-terminal entered:", start)
# Out:
# Enter Non-terminal separated by spaces: S A B C D
# Characters entered: ['S', 'A', 'B', 'C', 'D']
# Enter Terminal separated by spaces: a b d
# Characters entered: ['a', 'b', 'd']
# Enter production rule for grammar (or type 'done' to finish) SAB
# Enter production rule for grammar (or type 'done' to finish) SCA
# Enter production rule for grammar (or type 'done' to finish) Aa
# Enter production rule for grammar (or type 'done' to finish) BBC
# Enter production rule for grammar (or type 'done' to finish) BAB
# Enter production rule for grammar (or type 'done' to finish) BbBD
# Enter production rule for grammar (or type 'done' to finish) CaB
# Enter production rule for grammar (or type 'done' to finish) Cb
# Enter production rule for grammar (or type 'done' to finish) Dd
# Enter production rule for grammar (or type 'done' to finish) DdD
# Enter production rule for grammar (or type 'done' to finish) done
# S->AB
# S->CA
# A->a
# B->BC
# B->AB
# B->bBD
# C->aB
# C->b
# D->d
# D->dD
# ...

# %%
#step 1 Removal of non generating value

gen = []
i=1
for string in productions:
    if all(char in const for char in string[1:]):
          gen.append(string[0])
          const.append(string[0])
print("Gen"+str(i)+str(gen))
while True:
  j=0
  for string in productions:
    if string[0] not in gen:
      if all(char in const for char in string[1:]):
        gen.append(string[0])
        const.append(string[0])
        j=j+1
  if j==0:
    break
  i=i+1
  print("Gen"+str(i)+str(gen))

prod=[]
for string in productions:
  if string[0] in gen:
    prod.append(string)
    print(string[0] + '->' + string[1:])


#step 2 Removal of non reachable state

reach=[start]
i=1
print("Reach"+str(i)+str(reach))
while True:
  j=0
  for string in prod:
    if string[0] in reach:
      for char in string[1:]:
        if char not in reach:
          reach.append(char)
          j=j+1
  if j==0:
    break
  i=i+1
  print("Reach"+str(i)+str(reach))


final_vars = set(gen) & set(reach)
final_const = set(const) & set(reach)
final_set = set(final_const) | set(final_vars)


print("\n Final Reduced CFG \n")
prod1=[]
for string in prod:
  if all(char in final_set for char in string[0:]):
        prod1.append(string)
        print(string[0] + '->' + string[1:])
# Out:
# Gen1['S', 'A', 'C', 'D', 'D']
# S->AB
# S->CA
# A->a
# C->aB
# C->b
# D->d
# D->dD
# Reach1['S']
# Reach2['S', 'A', 'B', 'C', 'a', 'b']
# S->CA
# A->a
# C->b
